# %% [markdown]
# # Oct 25
# ## Missing
# When I run the script, it only works what's outside. If i make a txt with
#
# import script
#
# print.outside() it works
#
# print.inside it doesn't: it's ins
# ide the script

# %%
# importing modules and ibraries
import pandas as pd
import cartopy
import matplotlib.pyplot as plt
# import seaborn as sns
import time
import os
import numpy as np

import piplite
await piplite.install(' openpyxl')

########################################################################
#################### MAIN ####################
########################################################################
if __name__ == '__main__':
    start_time = time.time()
    program_path = os.getcwd()+'/'
    print('working directory ', program_path)
    # defining the paths
#    INPUT_PATH = program_path + 'INPUT/'
#    OUTPUT_PATH = program_path + 'OUTPUT/'
    # Read the Excel file
    df = pd.read_excel('wind_energy_data.xlsx')
#    df = pd.read_excel(INPUT_PATH+'wind_energy_data.xlsx')

    
    # Extracting the header
    # Get the header (column names) of the DataFrame
    header = df.columns
    print('your type header is ', type(header))
    print('your header is ', header)
    # Convert the header to a list
    # header.tolist() converts the Index object to a list of column names,
    header_list = header.tolist()
    # Print the list of column names
    print(header_list)
     # Extracting the variables for the dataframe
    lon = df['Longitude'].values
    lon2 = df.iloc[:,1].values
    #print(lon2[0:5])
    lat = df['Latitude'].values
    cost = df['Wind Energy Cost'].values
    bio_i = df['Biodiversity Impact'].values
    #flag = lon == lon2
    #print(flag)
    print(type(lon))
    
    # Printing some basic info about your data
    print('Your total cost is ', cost.sum())
    print('Your average cost is ', cost.mean())
    print('Your min, max cost are ', cost.min(), cost.max())
    print('MY FILE LENGTH ', len(cost))
# Out:
# working directory  /drive/notebooks/Advanced_programming/
# your type header is  <class 'pandas.core.indexes.base.Index'>
# your header is  Index(['Index', 'Longitude', 'Latitude', 'Wind Energy Cost',
#        'Biodiversity Impact'],
#       dtype='object')
# ['Index', 'Longitude', 'Latitude', 'Wind Energy Cost', 'Biodiversity Impact']
# <class 'numpy.ndarray'>
# Your total cost is  14943937164.42
# Your average cost is  2988787.4328840002
# Your min, max cost are  1000434.43 4999153.8
# MY FILE LENGTH  5000

# %% [markdown]
# # Oct 26

# %% [markdown]
# Argv is what you type <br>
# With a script you only have to follow the instructions without modifying it <br>
# Panda has problems with floats so add float_precision='high'

# %% [markdown]
# Plot s square ex, loop each iteration it changes which part of the dictionary it uses

# %% [markdown]
# word3: diff eq

# %%
#PLOTS
import matplotlib.pyplot as plt
import numpy as np
y = np.arange(1,10)
# the x will be automatically generated as a series of integers
plt.plot(y)
x = np.arange(-10, 11)
y = x**2
plt.plot(x,y)

# %%
plt.plot(x,y, color = 'k', linestyle = ':', marker = '*')
model_dict = {'1model': '--', '2model': ':', 'real': '-'}
model = '1model'
for model in model_dict.keys():
    print(model)
    plt.plot(x,y, color = 'k', linestyle = model_dict[model], marker = '*')
# Out:
# 1model
# 2model
# real
